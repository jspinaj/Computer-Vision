# %%
import cv2     #Librería OpenCV
from IPython.display import Image   #Libreria impresión de imagenes
import numpy as np                  #Importación numpy
from matplotlib import pyplot as plt  #Impresión de gráficas
from PIL import Image
import trafficRedSignDetection as tp

# %%
a,b,c=tp.detectROI("img/ima9.jpg")

# %%
plt.imshow(c)

# %%
a
# Out:
# [{'Area': 68782.0,
#   'Perimetro': 1002.9503554105759,
#   'Compacidad': 14.624602591058714,
#   'Redondez': 0.8592623653269104,
#   'Minimo Rectangulo': array([[ 486., 1600.],
#          [ 486., 1263.],
#          [ 736., 1263.],
#          [ 736., 1600.]], dtype=float32),
#   'Relacion entre lados': 1.348,
#   'x': 486,
#   'y': 1263,
#   'w': 251,
#   'h': 338,
#   'Primer Momento': 2.7815511079062127,
#   'Segundo Momento': 5.909678750558211,
#   'Tercer Momento': 9.211188517585693,
#   'Cuarto Momento': 9.06843297250117,
#   'Quinto Momento': 18.21016318646458,
#   'Sexto Momento': 12.024374306397254,
#   'Septimo Momento': 19.23598936065142,
#   'Entropia': -6.9390354,
#   'Porcentaje de Area Rellena': 25.8295371050698,
#   'Umbral usado': 85},
#  {'Area': 232900.0,
#   'Perimetro': 1802.6113877296448,
#   'Compacidad': 13.95194424719878,
#   'Redondez': 0.9006895663937449,
#   'Minimo Rectangulo': array([[2672., 1685.],
#          [2672., 1154.],
#          [3228., 1154.],
#          [3228., 1685.]], dtype=float32),
#   'Relacion entre lados': 1.0470809792843692,
#   'x': 2672,
#   'y': 1154,
#   'w': 557,
#   'h': 532,
#   'Primer Momento': 3.046752385644712,
#   'Segundo Momento': 8.5047249328237,
#   'Tercer Momento': 12.816367147896539,
#   'Cuarto Momento': 12.127993440559031,
#   'Quinto Momento': 24.666570648318693,
#   'Sexto Momento': 16.430212428422735,
#   'Septimo Momento': 24.889830139850403,
#   'Entropia': -6.3965187,
#   'Porcentaje de Area Rellena': 48.411426497967575,
#   'Umbral usado': 142}]

# %%
plt.imshow(b[1],cmap="gray")
